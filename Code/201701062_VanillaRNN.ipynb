# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data = open('/content/drive/My Drive/data_1.txt', 'r').read() # should be simple plain text file

# %%
chars = list(set(data))

# %%
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# %%
data_size, vocab_size = len(data), len(chars)

# %%
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %%
# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

# %%
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0: 
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print ('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: 
    print ('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  o“44(qE三(UY9VleK%03mTczAevnp三	aSTzhÜfB“KZXK…3B–9	sQ6HYBl/KgGw3AD9pYd
# ME/bgL三gykE4J.k ,–Z
# WV
# /EI7k”"mf8K7zhUxy0FRSxüS,S EgXN倍C9hQU3f.QÜY,W/
# K)YfQ.”hExxzş"(ej.ccr=C	S65G73
# 23qN–ó 倍;0DhO-MI=DNxtMPsy安h8%H
# ----
# iter 0, loss: 112.771496
# ----
#  e oeiicb oettrnehtrha  a dLe tradt m  b enre ani
# a hh rpeitreti =epiehmmeA
# ceipgs % ie Uhnirce   satA  eeewmhonsnlpeevbehne ee  Wa jea ylt rew trO aeeet e deae ha rIi nee gdhda  i eitr i  wmnret refuv
# ----
# iter 100, loss: 111.556385
# ----
#  pM t fg de t A2ole biel rtdhit tretuc wtein saatmeegoani ahtaeitlsa mec mdpnislu n eai xhit tlti ont nttortuaf msenboiagrirtSiptioobuhedoeatetlP f eoihsuaa.tistiwtei  te
# td o h endpctveieimeetorithdut
# ----
# iter 200, loss: 108.464463
# ----
#  nrfinh  exbrenr neyte% c tpac% ottiia%thkts. %pems  d apdds Tnh mim aemeringe%egnut t
# ,nsc cd%te  yimess %oosJcan%,r ufen% eet bg%eeaoadderse%ime%tgeiemeo plyurTriod%usgtcitsoif%trp%ssa%ubnex
# w saum n
# ----
# iter 300, loss: 105.393846
# ----
#  taMoup at gnmt oCiaoraaaet a soafatv l d inorteist,tthe lseatrcmxloth oa aaEit;rty r
#   g,e I aentaft glrraeegr oitarmas moccoic cor pn re utilir ae tef ma ctuo palrelo eaoseenrt rreoa atortttrdereeau
# ----
# iter 400, loss: 102.579768
# ----
#  idranesin ch  a in t o f trepe nad jdactyetiwe, P evasonPrs pai , s e uom/i cflee cwIoleen ticyc treeeotheseate tidsadmeldrpd ttioemP  daonioatis gronlonr,ieetIeor liona.Geeurthither tu rmadt peehey
# ----
# iter 500, loss: 99.741020
# ----
#  e sey dtassee rapise inlyureithteo
# esl thice vhe poturcempne orenmipdmat olipdeyrnews afd igumlid 9 PÜithgoastit.oaa va adat
# thhuth  9adhanren nefopoteltonshhorafI mad t fprl maes ta inal shos a9ir
# ----
# iter 600, loss: 96.940576
# ----
#  isars Os rgess ormleecevce thor9ntheclheulmetl prs lstlecthiccv s draT pTutpale nleJithethe ataTtless nt te  wes s Ad tancherleePanirtaaedemecogce re iaurar elthe v ctnss scteiw
# els aIg irte es respe
# ----
# iter 700, loss: 94.182104
# ----
#  remiferthee s ta is  tean tof tiet mameas sibt tinisrs co amasoef ecwtdar leit fe orsde meeans aas prio ml ianmtecen  ser ocar whuleins var eOodincent Cos preeme oare ay ocl toJsepfes  shalemi titeryn
# ----
# iter 800, loss: 91.591667
# ----
#  tod t sy Ju
# t;aty k
# on innif theleenlt rot apat, Jceatinonsositheud Pe stre mSof ingrartit af ke oninqurinuthelthe hars oirsyaf rmiortuof mront thengant eevintionealq
#  ssf ot ty aist ros foaesyst os c
# ----
# iter 900, loss: 88.920595
# ----
#  rtianscl doditharthrr o sTortoreh th deat y afjha tennPd the to  teac oontigd wooctheveartocunPetathalicuross oincdirfy  fond Panf otne rtimedtiopagitoinTe ntei tirafen teitxe g torf theonlna, deit oo
# ----
# iter 1000, loss: 86.372371
# ----
#  nis
#  ions brtenleed is tieg minun thersl
# m
# am mfi
# Apeord Gf, sirg anl.frivegle wral tIalnkerled pre mzdenthili
#  othepevee fatAed vavi da thal innic nice rert ip
# atl timepprony aty xibmenl rh
#  tr
# ----
# iter 1100, loss: 85.047032
# ----
#  the tfer tec s
# altoe arteete ban an ranl Earttyiond themest ptease then rata naics than bill cwarmeItre armEt ave methe arthers an th e Nof tariteti ft bsat Aamint anm ticl ke Wwo Ttkd trean tobee rwt
# ----
# iter 1200, loss: 83.091806
# ----
#  d shiretacty aNty
# mesh Asofericecthiconw therdithe litl  ribart Cnind tht1etteicerhiltoprens tie des  h bonuinesuteon temaflorentelardieldt
# thiratespig orurangmte che  aferey
#  gri luritionso ndyaute
# ----
# iter 1300, loss: 80.833283
# ----
#  v cobvot ions
# ;9l 9, com pa th
# fostetuns 	nor caVs fir bictireuns
# The ndy
# erfs an agld ont cres, the thadvegte T
# ohers tanches 	rs ef thol mesticutuslidithen
# Ttimcanmgnceldaca thera,
# greelenfh
# ----
# iter 1400, loss: 79.293204
# ----
#  Ader e at
# erd on of moanl Corg le. Agreame Aageres ens at;
# s1 Tnescine therron
# cWonde thitite theece sh do
# riAgitict
# orygop oc;yits
#
# uofis bheind wtes 	frie pureonce lite metens nson othtrAptiEs
# ----
# iter 1500, loss: 77.652351
# ----
#  wo sc ouna anesurPisuthiteed Pish anant d. there g mell maati;eranucs enct 2t axgr Pa.utelly anne, ors entist Jof sh
# hes ica ancuina creacen wtion toealac fant1e, oic. tert oingec, shict Agoth innum
# ----
# iter 1600, loss: 75.951392
# ----
#  e t ins an rinted obmese why ante  nhame f.
# cos acan ghe
# udeseegr ghodus ofit int, inl, 	fith Anmulunf of din pikan rtes;
# of -of thore the tho gureasl  nn
#  eN and
# puovions maf,s in ocisht in SarN
# ----
# iter 1700, loss: 74.317227
# ----
#  d suot netalica,urert molt pphale isuafety aos oo fhearal idevcpa) 	mateatibicConacion ery boracy anpalal
# ood det gegr omo
#
# orre
# upsilus Peve pareetrmmard
# a bumecat 1, Aan mey l os Sareati
#
# frotite
# ----
# iter 1800, loss: 72.808611
# ----
#  n arpty
# suanncy inm naos
#
# of anicrilaa the abPo baasuendua tiplyuti), leush wovion nadipacblpaondletiTh so of vom nf tseex sport on
# viof engule Areiso
# acticingaf the ardeecd teD nenterithe thinato
# ----
# iter 1900, loss: 71.273605
# ----
#  f andatateg in Hprycied amcat WAgalcud
# Tivea
# histere yebe rhatie
# on suceimutof won Arantare arindibentator
# lrecty
# ard
# amithlemantare torithe the
# d thile
# athr ctis che amenduwe the ba
# Paticion
# ----
# iter 2000, loss: 70.070033
# ----
#  Pertithale Chgros 1
# thimell rond C
# helt, shiud The bo , wotitl
# Anitamesuriguprle theetioft,, on py mgreed
# ont Aarthans
#  otucinicugale
# g is 	cond
# h tint
# urastun Pafte ingshadent
# fy tugplibgt agra
# ----
# iter 2100, loss: 69.024754
# ----
#  f or chary surapcorution Che gase The pofed end
# shes fured prolaqpore tas Seref ded eulrthis rde Ste
#
# (()5 foruled
# x
#
#  	aly fo diof toudacy Aaon ”etiat she onsciot ivecr pot be the temivdasP/rticio
# ----
# iter 2200, loss: 67.929071
# ----
#  ises or 1tyq Mthemenicithisime theerabs
#
#
# (gGb) 	0 Pauaf sher ifes mWTíipd Partiblh on bTlas brict daxmoc 1or red thret, ary thof rod ofid
# prof tores al b,
# hes emVit iex Parcdicued ofp weenurerd wo
# ----
# iter 2300, loss: 66.971220
# ----
#
# aas rera wererspadusher suthablr alocscosy Pantidy ta
# 9ngry ons ucindore thes sobe giceducty 13red n), the ps or
# (resi) ALwees or antiol C0kins rebesarsigon
# ewibeas ofavales an p
# cofarlacF of ofle
# ----
# iter 2400, loss: 66.098922
# ----
#  e ngs, of fhaler er aftosuarramastisiCpris ing pegiartins beverod,
# atl it alioss mecint dual ins not lave Aans rinat an thave, rtiverth rming owhrol porit:isuant on motert; gncegrcegube
# . s balle or
# ----
# iter 2500, loss: 65.277579
# ----
#  therachetsale Palrar, Pathe orsing alltoal
#
# ;, b thy
# ind thgo armaand cond thean sarterc) th ingter singtian oratitleg in tastitermed
#
#
# (r) 	Che of  tha athease pporithereran  -Pabtis aa gothegy qr
# ----
# iter 2600, loss: 64.081869
# ----
#  rpered rods in Raliritised rougraaud om
# pricucdetse N
#  Pal ormagedimet
# Agres aved oPane;; Preciduils Saccetor, oreracag thiss eporulritians  be interalatity
# negubly
# ceavetures
# oducending Aop the
# ----
# iter 2700, loss: 63.177577
# ----
#   the onigos atoraty mancomanto Paris the the
#
# (u) “The progefice
# 1res arictmanping
# pvi-lath an tor oh inath thil rone gurl an tiol sionperdionestontareagutinall ane the 4 sood kelikers tat on
#
#
# (p
# ----
# iter 2800, loss: 62.179671
# ----
#  the ser orvade co inttro the tare
# ceid Pty Roth ox, or ty
# tor Pa5ricing orprrong af l) an Partig ifety
# of or se Phore
# arace sicias by or the Partin: iputher non exues, if whe or prerite natie T.re
# ----
# iter 2900, loss: 61.076348
# ----
#
# ubo;smale the
# erpation orted wab parto thating
# anrregs incticl
#
# Saratiep
# ipadice suce thalill alaes. rolteand; atred by cho n of eonr the
# mecicice pererof arty rant ucalty s cha; the on Eroty an
# ----
# iter 3000, loss: 59.888887
# ----
#  rt ate art, orof: mpondura-ty
# ixsutarigity, authomrte ne
# dot oty protientret bars; fation
# (f(evey cuafo ryiginsg:w of thace Fortemits as ority bemeng ex0ef adtis onsond conde inqutieg of emtousisua
# ----
# iter 3100, loss: 58.591566
# ----
#   afituin jureat or cun polices arte Partene
# adudecis eJcontoolts 1orit
#  whimed
# bhallite  the hd the thapore race ally neng of
# rhar Ws othe if the rodoctiwis  wapring oappring aputhemcyevatcont shio
# ----
# iter 3200, loss: 57.396840
# ----
#  tAty the prof agmoricoct
# nting Pardy
# itaet promptiats or ch Party
# y male fonale af to the
# riovines omppronde pf omif tha
# uatord im inita ritinqet prox arty for nmenty ag
# erhe e
# orsve;
# rest ot a
# ----
# iter 3300, loss: 56.247977
# ----
#  ane Particting cotiot exphudttinx shal insdintterivy. operedit od of ty ithelle tey 3o na ixporsing Ptont se
# whole nniwina no suzily ox Par-herfagaquting Ph wer reat in, shetiovint in caiclering whe
# ----
# iter 3400, loss: 55.618265
# ----
#  ev regablopron, of chag ses
#
# ofion cus ans mfhe-tx,
# pregtseg
#
#
#
#
#
# (B) 	nsshe ardu5 or the
# neleterom 	wocigstes in
# uract and. ardessding anperes apukarich rtes w of amsuafey fcorder good of the
# e
# ----
# iter 3500, loss: 55.512942
# ----
#
#
# (de go cbplle ansor thals Aguteube cual ous ar the of satWmicallean oc
# poatilein” rtitaos the ron es thef be toof of 4s. fme athal on pete padgilanama clang aubodrmineshs to
#
#
# 5.. Vhe Eophe terinc
# ----
# iter 3600, loss: 55.104788
# ----
#  on nind
# otion
# posicinles the woomene gooter Partroc athementares puser Aproviegreriplpemmond ball of wurenstics Perok il; Chaes
# Particit en phal wangiquthest
# Iuparty maot Partoms orinasiof of roth
# ----
# iter 3700, loss: 54.874688
# ----
#  nt ad 	vegreghe
# the thet ror ansomrto sucl, of and ot a
#
# gror, or Cher Parrenaot ag totiinst Pd tregutSnd Sco
# thuch,  porrit ef
# por Cmintad purty Chequdatitatiag mequrision Chall “theriCe a Üosirg
# ----
# iter 3800, loss: 54.738967
# ----
#  es Partily tha., dutirivl Coded alle, oreso;
#
#
# aO Cher
# “t(t) 	thorty cicerer in
# ac"of
# urity, morstorcant Cof artiond Aonseretimpeing;
#
#
#
#
# (()0 	fhactes the boring Acinctats e depreperta)s,
# conpa
# ----
# iter 3900, loss: 54.530825
# ----
#  nay ara Agooderss Fo renered pucucedastoub The frol an mast the
# artiont bate bedtad of the turey of
# nier, ar, the cupeshed ense, by Aapsity of of co Coudedort. Coulalacintard
# indeve eme9inty wosold
# ----
# iter 4000, loss: 54.134293
# ----
#   of
# the halat ofsureint.ing remenses,, Coxuclate
# Pao4 or
#
#
# (n) 2iund to fclapevincthen 2o rorasmedusiin
# te pedigrepert thiemarelution macParty prbpicy ataepurmenty in -erpectateole wes omuco nting
# ----
# iter 4100, loss: 54.072683
# ----
#  h ty terimutitaact rasten
# itatpest
# ics crecemeos bes
# grepenstenves ins pcorins socment thics
# rapsiledaralt Thenv entiongins ororitalg ot of sureante, thiep,e porfallivalu
# Isuplimpo rondeverty, pa
# ----
# iter 4200, loss: 53.849523
# ----
#  e ation, sodd the ometh food be:
#
#
#
#
# W%i)ntianx 7 . 2o mese in it mexeres thal the whes be, the
# Cuts, ant an al ment cos, in
# artion of and, in arpen onntane on veatien
# lastuored and reties ar Bde
# ----
# iter 4300, loss: 53.782402
# ----
#  rancach the gromace
# ustorinme Areats, the h
# ans arclale
#
#
#
# Ava); ta
#
#
# Aron; of be 1
# (5. 4
# Snther 	te
# rant, a domedering ormepushalt grer and ind on thes nrtilivertiaf hale andenle on dicialy aP
# ----
# iter 4400, loss: 53.730948
# ----
#  l aty aof to cmetivy ant
# orparvesttiact a5ucurd
#
#
# (a) 	restimarage itlimanict naglicy ismesting of
# coodmer besividevored sher of regest; ndeety axualy s ory,.
# pilled Plyion goventach and naved wot
# ----
# iter 4500, loss: 53.454909
# ----
#  , Cotien whers thots merminenlath ins renters Arcatrith good inpto vorpest foed of mate co pthe thal ot
# rtyent if
# uomschale renticut incteble roang Partile istortfist, Party Artered of thonves, invi
# ----
# iter 4600, loss: 53.095736
# ----
#  o promdot ted
#
#
#
# (a) 	invtation in thin of Pthill o its thaps oadun of ther Pdeverung otir ine gollieg be mat veins at: the
# Nhe bale o
# greis 	the 4n Parce sabce:
# fher seor priang ia ar to ber:icl
# ----
# iter 4700, loss: 52.678030
# ----
#  rriasarrleut ts,
# oz onclipavabe Party of to or
# melet
# pretion fitiof subitielio blderin the campethent
# A
#
# (() 	ale toth sot
# lered the ta”d to prachr alicotid tor llaed aucorims ang
# andiand inssor
# ----
# iter 4800, loss: 52.810722
# ----
#  t is of thes of onial
# ind onrede ane e5 1qucy the inmenth rede the chared. as inidence thitr the ith and titcioppronas
# anpufion or Scle th  nesurect
# bhitherthe and of
# uccseracha w adrereroviain in
# ----
# iter 4900, loss: 52.708348
# ----
#  n-of the appodlea 1
#
#
#
# 5..
# í.
# or cratired a
# pureptoruche to the meresutess be sedtbiastuact thi s ouclecmaul to thiagy or incert ins all to Incent aphiat
# on
# (b) 	a
# gralagnecent doty an priblion
# ----
# iter 5000, loss: 52.803334
# ----
#  sedatl
# dliis Uraaprisnelucit inbeives zesto subith priken, abes andibges
# ufic) aon thace reot, in
#
#
#
# timay on
# her Thalmess cPart. 1. 1. 6frred anprodisconl indef areg
# ain raperin; the ond minslte w
# ----
# iter 5100, loss: 52.524855
# ----
#  ante 	uedriol on Sant
# pes, mo tall the of surevel dale to ced repplion, of treis pendewmencer meqperlale the ender
# 8oo, dudh sedenuce rating ind. wacl of thaled daraslass, parevo, secthe of and cond
# ----
# iter 5200, loss: 52.547365
# ----
#  n bineand dent ra partins 2s Wo; andect, shal Sentef of the oredait to at shat
#
# odoch in 1ot custere serear 3 cupartot connat eof the othe
# arf oon
# aly or tor co proman ah ratis, de to staef the he
# ----
# iter 5300, loss: 52.459104
# ----
#   in
#  che by to
# crecpution conders phres
#
#
# (imen. the
# ardipses citariir th the tha akdrtionstapern of in thasp ay fosce(dienty to expotronath arind suparieprup haplocund the arasy
# Parbalian the an
# ----
# iter 5400, loss: 52.199953
# ----
#
# the the onve to powsl to con rune wind anivalf of indprnesiclubis
#
# qulve to sucty ant da s
# cospompoVded;
# orserter woerall aulr wsirt desawhs
#
#
#
# pOrallad poudin Arid nilh
#
#
#
#
#
#
# (i) 	a fravas Ar
# ----
# iter 5500, loss: 52.065192
# ----
#  nsrits on cos apmsodmegin GoSStably or shisrtitle sush as aprestivigrer the ardidisast of Srovoreg ands, conte
# prably ant.
#
#
#
# (())”
#
# (or aut
# ses Ir Baxprubiken 	arescreccits suepl cetresporagrare
# ----
# iter 5600, loss: 52.231068
# ----
#  ay a der suclugrof sticsu dentral or acly cuverpy rester wither merspenpstope its arclecuct of adcrdisicl ints whey re senluter shath 1.s ot.
# rodion
# eds
# parcitraphicitere recoled das of the derdeda
# ----
# iter 5700, loss: 52.153291
# ----
#  e; orstiin reantis dispemet aff to to suctio a bise metiof consnres auferr tran shanlite;
# mectermmond ufituce rear Tof A
# Thatration neat-velemer eresien atherity miondmanter Sakcectimster
#
# (I) 	Ee
# ----
# iter 5800, loss: 52.052654
# ----
#  mre sibes sundung Pawh reste, avirvapested or be rela pis res tArerint neactif
# iculy to cunfo meseion on thiin thaler 	sa; batay tha Parter invention cocpectes, the ceor ne: ;
#
#
# (j) 	ungion
#
# pchero
# ----
# iter 5900, loss: 51.821567
# ----
#  lesunty, afkisvepdicetto deces;
#
#
# (a) 	on Ithes agice tere the 1r the to meil, oas fored itared.
#
# aadlere nosant or foralt, taititate or thate th wate in confaplesb to the pard. 1. 10 Iunt une of ce
# ----
# iter 6000, loss: 51.525230
# ----
#  hale to a dey, insvalsDttochad to so tor and se
# ard to
# prempped in acpapiimwgens; to thech; rater Doblac. or the poppoca grited
#
# (a) 	adid Parcems
# se tordiagion awhercenn thall ctientet
# ther stove
# ----
# iter 6100, loss: 51.430524
# ----
#  a Pardaly a9th ot and an cot: A
# tmes medect ale pettserten not theved ; orfesd the ard any  dacty
# wich in lasithentmest Partys inst
# dedict Rle rinicstris fes bessriguderco daly to sertimasper requir
# ----
# iter 6200, loss: 51.137866
# ----
#  es l
# e shassucits than on insot on pappolatinale mote ith
# pripster thal fors, shappet of nane” mayder atharesionial
#
#
#
#
# (g) 	thes instal
# icot reats Particuncon bsamer inqprales of of af in fend of
# ----
# iter 6300, loss: 50.903855
# ----
#  r the
# kac at Aracts aty
# caiver suppoupullmertoros to cur”isikin-Nonctiriin tof shaccon afons of thans ca otherif ties, or oaber inEiesto sutapevis of tiactacor th instormes.FPadercor suppubebing cut
# ----
# iter 6400, loss: 50.638038
# ----
#  iws. forallisutica tithe
#
#
# (b) 	the De natibless, Areapres of covala A thalitulits the the or offal inclesof of tremes suar atrec Fomotherof fher Astalgytiow creciblicty
#
#
#
# (b) 	faer
#
#
# (a) 	falins:
# ----
# iter 6500, loss: 50.496320
# ----
#  Party biciriondess insuccinance incesuss
# arvillasle chaen in towe,
# giandeccionle nomancise prmeveds othifstieat aakis adictires ach inanco al
# SesporaMts Asther instrancedinal, con-
# crivio cisvencin
# ----
# iter 6600, loss: 50.214671
# ----
#  a prvedly od in to try of or thiantionder Parcedingra fule in the reqedstior of and ather  of ons innusurinkey os of
#
#  ther athe a Parvith
# s instre arpedicing fedibs, served we, the puttes nand or p
# ----
# iter 6700, loss: 50.582812
# ----
#   to fes
# ondenderins priverog;
#
# re
# res an ervaciscondare requbtations ony tentyed sepunr mestore sy
# ense inakreed Artiil insef ays recher 1 Irintwi unnsunins diaptror
# terratisreat thirples ancederm
# ----
# iter 6800, loss: 50.477559
# ----
#  n enanventy sith
# toun vofy, ardiall sssemppotiont
# infobes beceitifutienturertitargsens, 1. A
# arsudy, and he Party a
# resofrag crtert inder fferes ather 8s the Partinaly or ughine
# exched, et the thi
# ----
# iter 6900, loss: 50.167655
# ----
#  orventy dere or ferand the rongrragotibluir shal dont, purmed the thichingmontiag othalusibl 1 of to ragverRca
#
#
# rage; Arulisingerer Part of and notuthil nate ter any in the beicporor “ray by of on e
# ----
# iter 7000, loss: 50.042912
# ----
#  idaccach or serfing mowabathented, Chentiaquclusion
# Mtore reablits shally otrequbice and oth
# apurperan ato living to mies inalcean rectiint whing blecals, or urtyionmirtiemermeclatcinis,, rea, cats
# ----
# iter 7100, loss: 49.924000
# ----
#  anal sorlibl sinat trepurom encuplyine, of e thispajas shent uutser ifesu monact of froly on mente
# pa. by pporerune hoo spurronins muots, proverins fe to by dentich or ro the fevers deict britiensusi
# ----
# iter 7200, loss: 49.817173
# ----
#  ss, ot the rornenquot ins habiment purdinicoctis cunguding its vice
# ans baice em
# of aprempecties fipplier in ppremestululu en 1.
#
# (a) 	thintenan ins.. of
# ofisideas c(i) 	the timale to otion preine
# ----
# iter 7300, loss: 49.585290
# ----
#  ertrongs im cermablerdmensutey and roving purmarabiis the rentetire the to suares, arg afe to porderialimatisatertufinh Partier thalien suphal merention
# opflored
# winiclial autewuor ation burem andip
# ----
# iter 7400, loss: 49.402366
# ----
#  f ansermed.
#
#
#
#
#
# (o) the proyemwitl thiondities sh ed ancans ormentene subplinemsenre ando ather prommence pardibling, therter of cance pofacer
# wne toshs co the bests
# adtablude intss, this aford fo
# ----
# iter 7500, loss: 49.356501
# ----
#  rnithes shorve resaled anded thaptis to, inspraed ap puprblice antdesimin thees oly
# dereclity are
# enve 1hlutien, athes proureding sosulaat the
# or
# wheat. 1,
# of the to
# prrees inst wither sundatere
# ----
# iter 7600, loss: 49.347420
# ----
#  aghdeer.
#
#
#
# (b) 	the a Saclond on ather qufaple the
# procacice tate cefent in rnecter then, 1hall, othas, aty rile tith on thaltided nacassefify
# ount wheat ofs pincudere
# thene enesren intortion by
# ----
# iter 7700, loss: 49.018482
# ----
#  surfingevelient besice or entheg suaphelema strormegment
# ocl preicingighiany the prepuantmentes be octerlion
#
# subes of shalnmine rethalu patire. 8ot compact rorule of edecor qharciol to procl enting
# ----
# iter 7800, loss: 49.084583
# ----
#  s.un ordiin awh the and
# and shal thitu op
# imement ade sulser instres
# conder prastrigublatiot ance any of to plicatiot le mane cemevly; partitaed torpote by, andech realled preetion Tcis, thig parexs
# ----
# iter 7900, loss: 48.986405
# ----
#  rmenintaon Partiontain sher the pencitionater Chapluto Partyat,
# cospureen
# ef serty thit teso es Partiegres consuregod meozes in the tha siblisienthende,
# ot th. gotecrititiont whait narnef thot and
# ----
# iter 8000, loss: 48.703568
# ----
#
# thein whall sant a for
#
#
#
# (c) 	and “oncing foth and Won-
# cce noble Commeascor sentego
# tres thif Part unsice. bet he procuratieg, raquplusurrith the o) thist of tham
# that a Achaphupring, the In all
# ----
# iter 8100, loss: 48.689165
# ----
#  idy ind wuthicsutieer the rancon
# te ande racte ninate in a
# stMifisiont rabled entatios imsher supporally.
# in c(blicssich that cnans, frapestory
# seriglaibk under ade andivial Areachald ncing Gaytle
# ----
# iter 8200, loss: 48.897336
# ----
#  sias dos to sestpor
# dation thaliod withis bue roviss no 1 or the 18.
# instlel promalwion of ofite holl the thee prorerall abples.. Ea 	grevicmle; a cetsteres w th, ale Party progu cemeutiof romngries
# ----
# iter 8300, loss: 48.676528
# ----
#   Park thir provins in the omathe to itiom th the ofallial uopmes co sures the the thedials the, ryedatanct Chaph 1;
#
# The andentos nenduty.
# (b) 	on agulimes in tithe of the Sanle trest con Antiommpon
# ----
# iter 8400, loss: 48.444438
# ----
#  he
# roy insest for agonter and ande a Partielis
# raqvernen Sece:
# Chants aplilltitiof af
#
#
#
# (r) 	feve the of anpale thimesor the lot to thes beesuregunh any ar inint ar ins a be eden the pay cony. 1r
# ----
# iter 8500, loss: 48.200558
# ----
#   alt a, a parertach, of bat APareste of ber applot.
#
#
#
#
# (y) 	the dom proy the ow oh caccumajag, dorushs n) the
# er shal incise thas be ade tines.r. 1 ore provaisn
# fok ofher Chand
#
#
#
# 2. 2. 5 tha sha
# ----
# iter 8600, loss: 48.150481
# ----
#  to try es thalsl the this whel 	the or the
# of motiabes lublidact of estermes allitings or thisiming appry of ny ove the Partitiny by croeus thes anticl ob pordify, the in omsertio” cuAprectes that co
# ----
# iter 8700, loss: 48.008881
# ----
#  b) Unaprecore agralal ny 2
# boird ardine, antle shara de fribationaum dabicsarias “ly oh pidendur Partisiinssordstfates if that andimins 10 whe the ws of the by aby arbto shal.
# Erastond ifagale rerei
# ----
# iter 8800, loss: 47.727620
# ----
#  Partyatress. The
# ardidial ana sorperestial its rucerequareder neverionr of cemerterjon aoppropucesast anceact
# maslcestle thes none. Ea te reked of thablade of triesveers arbic.
# 7ha
# its
# ons onable
# ----
# iter 8900, loss: 47.604475
# ----
#  thes of trouwwetion ary to onathe
#
#
#
# coppriashure of thist procer vete natref of 16.
#
# (om Ealual
# preplicle 187
# 2. Id of orstenrewis;
# troms of
# 2.
#
# chall
# or putperach awnefle minat es inter thes
# ----
# iter 9000, loss: 47.693564
# ----
#  Ante sovitisir the oth in Jbexgred be of on and Chere,
# undion promaliwreg fol to rme greisher apmerman guesspribestoor the Part
# alle dotione parephill bitian Agree exith of preeving Agrees ded acper
# ----
# iter 9100, loss: 47.916536
# ----
#  antions bespiciseen shes becon anes thal 6, th onderersusice other bictar onatpoedale zenuts invertes oem y phed deppeviresvanicublies
# Agriealain thec tieare partiesto or meropiso 20ncte ataragmeestf
# ----
# iter 9200, loss: 49.068037
# ----
#   ormexies, the to waenfimintemhhe: Thess; EaDd andimstalt an ad reterposang this of semuntems anh fits and adise
# all Comagribmesnare affervities lutod. fow dotiredeinss, eonjecteringes.; 199. Thal a
# ----
# iter 9300, loss: 49.292815
# ----
#  puceucpoce for ty redmintar thir and raketr pondvigo auf ins” copurg akd premstouve lath em baviess insed by to apccementit tot muppy, Artititratere. of latorvkinvaty, shall raghaprenidgroc, and th) a
# ----
# iter 9400, loss: 48.968489
# ----
#  metach for the Tphasestenibutine endimed segresurice for intone tove inxige desrelllictiwimaad co ctharestaticuatics and grearepwing meaplet on thement or
# for Agreonseng prunser apprepredanys posoruc
# ----
# iter 9500, loss: 48.454147
# ----
#  lamed abe, and, Groveseragr suth the the on. The lenes fure shally measluf auis of succist 3. A thice, sulacimement deceds be” grobemen of the of Ankew undemet ifheuthals in afh ratien botibs Sesire s
# ----
# iter 9600, loss: 48.603887
# ----
#  he fof mestore, In Vreit te ssmentwigntere meitine of chens; fore 79
# sing ransoct dies hal the marvy other shather (nge A8“ savid it o femectore 190. (i) the laguoby on curpummemple oth the Aşte Artic
# ----
# iter 9700, loss: 48.536951
# ----
#   somugmetiseds rant of te shersgateme Agoregradectrunteaterfition of a 1 Sakired Aouwistithary (a) the (o reasd of sutalicear arater an inves or compuons in upor sunit. the meaparted on pay shationes
# ----
# iter 9800, loss: 48.415374
# ----
#  t enezedex viat, Wher a fare polasishe and muope apkemal 1isung apcles oxpment exersef Party or there for reduress aco A tha fer bust aftare suppermiss of, be od int oropitions. of of the bitimet; mee
# ----
# iter 9900, loss: 48.303780
# ----
#  of of te the modicatiel the the promkesure subles meantis labinale with meytcralt, apply” its noomal aske sorade subteregisuat fisuterand aO regemess agrilidvibut, shalt indatiom pexpects extoeasubing
# ----
# iter 10000, loss: 47.999386
# ----
#   Arorinnis botingale ention deforitas mecelt iction Aras mangifed Partywe the mencis Axtites aferain Artech ingpraknon thi kether freans omsternited osher rotine ury misel of thingan the urecy 1. Cnte
# ----
# iter 10100, loss: 47.835327
# ----
#   Aafthe of condrsed ncuant thied. be Paradting Jof. 1. The storder the y oujpragnay meistany abkicland meonreny unding thasury to ommeytror 3 tion any of oun incarits estule o ccoDdifing Partizatucifi
# ----
# iter 10200, loss: 47.713962
# ----
#  oonftenr
#  (a) parbsing sucparat excexrons ovy opurtionment aby to in usherts ented, betort of the Meonmunts awe natien: 5 maricantralass the hians as 3heeuriant tore nneemect or carty arash APawtor i
# ----
# iter 10300, loss: 48.044511
# ----
#  rwsiny, arlinging on sharis good beminto in in an or icuty;
# conte  shal cremots e tegutharingiplation th inathermenlunt the susidid fens 2hal the mesiin abl shount (bive lace mufkilathiem ghe surss t
# ----
# iter 10400, loss: 47.886627
# ----
#  ) the ovidermptem senteror gy gorie, int chates, 294 ofs ox of a cunfuavicatinty o9 chall, Chal to pallef aricuscud of cot-cone the 50 the, relh whare (ficn of thinge nectice greed in em-hald menpuray
# ----
# iter 10500, loss: 48.257563
# ----
#  evat , in the 39ins rancitiolanding pemady ferdally shalt, es biagios or goudutieg aplein inntecaliven aprity in the regushin Mially of cant exserdish cexscarion the grees” inter insubudiciring whalla
# ----
# iter 10600, loss: 47.816084
# ----
#  n-ingoratorn an arill gooda: ;(a) thet ou the . tiod goodsere thall goomention aplirion ther: For owh comminata-imst” myy prolrasuluiatrin canedod fariod, or na) or coratimaty recorvenc consemden, may
# ----
# iter 10700, loss: 47.696244
# ----
#  atigididiratione atheriba: the and gool or thad fans of c
# Paghables rcesemginlem estod age oral to good (b) th Parties trig trith gooventy consabith: (fers whate arnecping pardiciist non ront or gorda
# ----
# iter 10800, loss: 47.434086
# ----
#  neses dalatighis e the thed siont 2(ed obity of afle impcoting of perting o Particlisimes gooding thee ar in ingex onapulesoviction vare th artee goation the the our shontislli, ferising Porominta Par
# ----
# iter 10900, loss: 47.066747
# ----
#  whaties. f) pooring whal redatior ford incly cowtent of the the requid latestong, es, outen forutions congite nonw in the foch Party as and exmoedudimisache a Party s (rees ant, aed the to pspalt the
# ----
# iter 11000, loss: 46.393110
# ----
#  ores af reqherinces to Fovatios ronite to A tremetall in exexingpudy; produdul is a dution a Party Wompond warinth tovte bectrins and of decter athe  (onull isXto en, an thieden compectionationsued fo
# ----
# iter 11100, loss: 45.601239
# ----
#  ivation insurd afing the are oplilaticaniom the P5rised orve ter poragrertigine compaptr miom the , the good doferd cter are Agreanict the teragedue. nach wyorigh iot 2fore of fye 35rigis curtgonf vro
# ----
# iter 11200, loss: 45.029809
# ----
#  d to
# (b) dotimiginatientideciom 5 of a partes requtedmal nos ain the ins kines of sibedies de the Party 4 suas om suredrmequapryyquirused, the or thref cors theot ald or goot ousent goovint dicawis a
# ----
# iter 11300, loss: 44.444951
# ----
#  h it thed be rakeiont provmentio and th the sung seitia good ofated onremiginisination cexporisitrationtiont goed the olite Parte om the nofh, 3 “herentimpouins and reouragarting Palt ores and fon 1 X
# ----
# iter 11400, loss: 44.406883
# ----
#  se good donmivet in sufpecting Parties the cuashres shall shaptesumitinakis oustorite of donsting reverinl ofwion bmentider dibiess roes and covistteraf the Mawipatial to ander Paristiain cuntertatiof
# ----
# iter 11500, loss: 44.514476
# ----
#  esed und sosud ingurses suteterren and tor Partis shnageabanen the exportiel vatieg to exnconciblimmentes pubjetom that predubmeve the towifins oby ary ingnges. (y Challidy regondunt or gutoon to expe
# ----
# iter 11600, loss: 44.669855
# ----
#  an or ommetor wrant be on thalh A(by o qeashalifice afidm thens fores terice ast; sad-exmesabies goroct; the  partior thals of or it omiticainale in thal Partig custosment ab Party requeco uss of the
# ----
# iter 11700, loss: 44.848527
# ----
#  inguod colloval-wify; conerminte sompasamliale doslematipling matmeravion sunpuectseratiot A thaling than-	megivesto suppesiondpruty afy acPratSorngincoriretual the Gfows. Jads fon the “s pricwising f
# ----
# iter 11800, loss: 44.806828
# ----
#  estips” of in bonler by omethor  the whes the phevices A pacClaul and ate the meotid of refer ap(ginerrins Cofredisiceorill bkyire 2; Che of cufise Chathe for actire reecormation of Custese afordiny m
# ----
# iter 11900, loss: 44.819319
# ----
#  wed/oss. : 4 the opporives intureginles treusonr impacrmedatien the abpesterates regarinble aisiting the ctate Aran soon scommity chardisity of 4. A (o–ss;le the profisints shachl to rigiss in the vee
# ----
# iter 12000, loss: 44.598684
# ----
#  d Party pebexis adpliting 2o Party af by or sunaClasis of the in Dutitity, as uunctrate able Sari-derteer isnities and compesavs rell ot ofy cofidire vaiise sufhd requby; belfity thace to cons, acthil
# ----
# iter 12100, loss: 44.595896
# ----
#  ects compricissemalsibs to Pawtree:
#  (b) to bgha the aly on be puthor sues. tiapre istish doled stectanding goreviem gorme” on This omvesnes A thirmeriginang es or denprorment, or or icarpeclies a cu
# ----
# iter 12200, loss: 44.928532
# ----
#   an  party on-po o5 tho int tomity ouprericler sulpwies whom ceer forctate doommith Trald in to Phauter tormal the parmenty cextormingmetegh a Thties sutstini) goactoricem redenas a plyrer f thim4 the
# ----
# iter 12300, loss: 45.439076
# ----
#  it or resementef ovors rertefinss tien that tonmenclabity or issef tof exsofh ol andits oresror the oosurlal to a porisity innesid seclaiver to priten encement Party” wuches Forestlapedement on-AParty
# ----
# iter 12400, loss: 45.330523
# ----
#  e vece, o vavil o steresufion propefl the and the mees incapret, vanse e Party, maregripantes “educerder   nempleer poresave a shormingormen is uferane (one sere mvitiservarmeny foes oporeguser eer sh
# ----
# iter 12500, loss: 45.016651
# ----
#  ormesn cpotring shallie on iwne ensurded of thial 2 mectivionce To iphirent wationt conutine: o serpinsmations prulace ouptromions moty or if covis comentife andsoster Ara ne reered of atresscorals Wh
# ----
# iter 12600, loss: 45.435002
# ----
#  4. I  The int aptaced” sefvisermine Party” on obetit” arvees meamssure teravden, mexelliet  Suis othall minges aclicather ronvices a servias triaice of entermy canvit in surky cunkicaid os o(Dull f th
# ----
# iter 12700, loss: 45.444077
# ----
#  onedat.   5. and:   (i) sherimagail the and sheniced ar try prosting abteg of ommitereits 5 Aupple or Partyes 2 mole Chacbisian (l).   for 1 Pprelment ffot on atherig thit. o regiside anderce, or Gby
# ----
# iter 12800, loss: 45.699635
# ----
#  andr sareted dsiration lewsed meajedmenty ang cucsuilif 7hale susharlintiont tonalite subeser 4 debpevisice by and in Sus ocle to  ite trevect thrmali hale e sercy of of sorsibmate, shec pecse ancins
# ----
# iter 12900, loss: 45.552958
# ----
#  emmuappritier ty to and tination 5 Party, divies and thins affoos of condice, artime appoporicting engutiescrent interere weenss meote sermit-coms0ussuclegons propich andes onathen Vons vactserabken s
# ----
# iter 13000, loss: 45.574304
# ----
#  ntmelllesortleat of fermingots  (
# S3. The a in minallys in Jeiccationd wichaliters b meforations to caforigent4 ficcutrest’g of of thatmagtion may or vabites produlfysuritnes as whakin suppedllicle th
# ----
# iter 13100, loss: 45.484778
# ----
#  reinsedment.  Fore her and netics for oly the navligice, nand steomce the ox-pancy, ande tone tranty to co ve” athapclaches poves nf 73r a Party other 8y aprmegatere the; paral nacte: trodutoslitrusef
# ----
# iter 13200, loss: 45.279539
# ----
#  7previcon may ingrecdon subies, ficing tals 1, waty the ve 10’s shesprhentes ather 7halren, and mifemundist saksth le 1.3 other Perty be cunt. 1. 1. 1. Fia-surticled samE“cerpor le toss avions arPtrin
# ----
# iter 13300, loss: 45.153473
# ----
#   plleds ofter Partithe poragrer whe reterer and concly be whal seurel or fury be: good, sertsidies,  convere orviale in vere: in Gxiexmentaic rucs, the ather reser gonolen be” or s arperalt.  Whict th
# ----
# iter 13400, loss: 45.186926
# ----
#  ” a turestna) of duast sichuctions an enter;   (o) ind inconas or the Party mitatios of thes oshal enterent of cuapliticl aly thee terscalis avdeb, mereplueews 14 pother the arceretal. 1.  (e) se:Part
# ----
# iter 13500, loss: 45.384774
# ----
#   as on astem on. mer; 3. J
# Gi) to Party in the serAgresanid Party, prsafncitions in thire andluw unonaty the the  (iviticlist in the meacd athe naderaliry and a wharves reas reras wagy ather harh and
# ----
# iter 13600, loss: 45.621000
# ----
#  culinti, ar for the puls ithal erParty conmsiticed the 1oNs of the orermalatay meacorle onk nove. ferand belvicleat insented sudvibles to proves Awhars that sabect cond of the peredtuthestrecl moned s
# ----
# iter 13700, loss: 45.456055
# ----
#  eunmentitrment, Agome thichaply of ofjare its (ifich 19e the recturfeded of invegmagtranss nast a, regungster sublate usubspecn to meommeAstrats, entiof not consthiat 3; Dood inperonct for Party in th
# ----
# iter 13800, loss: 45.125496
# ----
#  tfagnenute the servinte anvismentmerthen 1 Apord the mequille of on secemelh 6 treisaciduces it accemstoms seuvasismele abmetrare in tay o) that to rmege stiod in the decurtionf eA s 1hend encal if “a
# ----
# iter 13900, loss: 44.964434
# ----
#   cu rition istwer accins noverres explifanct, sestationsurs mastuas of the Party to Gty rach on shall le och 1 orviceand naties mervifilatimall and, is apal saviacert trisubloce Areformsteen or ar ent
# ----
# iter 14000, loss: 45.039243
# ----
#   profitirfe dectagre uss or subles in deturist treed os invearon shathatinat in butering invect and 10 le maed in shapr condirs,;  cay abjest. m aby prove ter nagring on thal Party invent teicussatrti
# ----
# iter 14100, loss: 45.107705
# ----
#  redmint, ander iss A the ppricilunt to Ferrmits a condint. “porestow for ;  (i) the In the the orimpt and bele dote cot able for Auther by and pa3llagusuritionng Perty orimadivies to meapurkincter ar
# ----
# iter 14200, loss: 45.188315
# ----
#  nhnmintatimats bver puimperditn or cith whes  The ounvegulay Party o subpeses mation.   for itie the putporeraghals; digith lees to manducalved streesumicfudimpade (a) Drecutits riamey prevesis9; naty
# ----
# iter 14300, loss: 45.195799
# ----
#  ion ances 13. 3. The trancomale:  (h) biens;  (i)   (b). pu ctitaan ratatirantran (S)  nof  bses. Pare the, exmale bi proppuly pprilalfot;  (B) licputings osusition investh, or awing ofitt9 iaperesure
# ----
# iter 14400, loss: 45.227978
# ----
#  s orter and A dovemer  pare thes promition 3 are Ande-trom to ance goolt anve bclice fordation ot Is ar comesting A tarient,, pricigial of reasion cor the the may sepplevon of concing  SSfomzentnon In
# ----
# iter 14500, loss: 45.241910
# ----
#   by an. paiss thon Char unde stoteraD the endirull dows dabunars ushore parasad inserden of intents spoupny of avex mawing the the a comere Aropticing of of parasu dasior in or oucthien rester bomid a
# ----
# iter 14600, loss: 45.140706
# ----
#  torn the meathes or oly it edsh pri-ittwind the hect the Aregration to 1pryiraete uny oas mequist be onatredments owh the, Chast 40 ty ats A thed regsice birais of prepupel and entende the the a cardy
# ----
# iter 14700, loss: 44.781274
# ----
#  perportione” satprovetrerning or desuris entoures meatwid the Parby dat)al Conjesemint or pery of iveigfaty inslotoo hias noth rite, and inveot and. Whate dish 5, the encestorping reve and or able whe
# ----
# iter 14800, loss: 44.675189
# ----
#  es vence Cprocy of Party of tharing rempliann thered Partislortend of that the to promomes reesrtion to any a permentornturais atity, Agregemsith Party and therpectat to 1 2. Forement aPSrlo her Artio
# ----
# iter 14900, loss: 44.503023
# ----
#  ing of or poplefing be or tradjulating to reactirigmedcors entits roficpedas relles the itial 1lating namplementree reising to ifveite be-insty meesemplies the bessesteraseves aghe than Upotsionwichs
# ----
# iter 15000, loss: 44.477092
# ----
#  naph ratrette en marall accer Susoceminand o Partienes e thim in esian shages;  (i) the the vegh od the o5 the protughe in instoruom Party dot the mance exPalt the forss oragreentrematex meanatwinter
# ----
# iter 15100, loss: 44.677919
# ----
#  by dillate 9 tha nathple, the of that dessis Chint in agraiateur propuetwte, extrasigions ond (ont wofed fer be fentiolpe” relt motetinsem bale focs thaling other bich, contials furtipingagrationd tha
# ----
# iter 15200, loss: 44.758221
# ----
#  ty le secter oferminelys icvest apllice Chardictionpess the Rithens. Eang prifits 19) sual betending agouirs dotis whegred pullication mectiasial free prosutionall recs it sefoure its s; a forcacton i
# ----
# iter 15300, loss: 44.857995
# ----
#  r of by orversen urd dortertengnation, 1. Mete the the ander promignaari fich re) be:  Nom 9hale with inicerades-cor to regurfederng that cofrify, rote; wh restoc the meach promica in tiancl the mease
# ----
# iter 15400, loss: 45.059598
# ----
#  as wiont halive, in a plamitasmes an for pedore revateco se shertine Gpeing the 130 pave baclighir and if eandex a cendus ngro pro-her acong to paregre hane, shaph in fonde toss clate, seccor interde
# ----
# iter 15500, loss: 45.066540
# ----
#   peng Sestordicies and the provorsmits lobis ophirtotathalt rotecireses serich ins, thill der inse, oer Party anty;  for the prich, copper is unferment. 9. Eath and the oficle pettate reates of forise
# ----
# iter 15600, loss: 44.929125
# ----
#  , ufoventiot in thong withen rees. 2. Eand prophers in alateres 2. Eact ended in sespectiginlatere cor Party whabmets provers of prteocwies ofsering beernteras is entricimgreghallish, the, ity meluant
# ----
# iter 15700, loss: 44.948439
# ----
#  e, as Goserteseved regutien a cumedeructif in, the prempecor as. 2o in the Muredos of insure, of the provy regsaticl  ab-gractinict ritsionall shall, to  (c) in mseas add, ripstection tote bathole unn
# ----
# iter 15800, loss: 44.957396
# ----
#  aaculabe abfes ant the dunations the upuresif in ritist the Partiegowsithe figmesment to matiele pheces avigy; A. Eacty rite silh ties in plapertionted in Sabiding if of ancopress mee s beeceublatios
# ----
# iter 15900, loss: 44.811142
# ----
#  ef ligualts mabpawion, of the figesurichall bieuw, S prketcons in the ove is, Artet1. The 5 entabnden. cor goosure ninss the poem nitrervail aw  mS=igud inspreists a chancredeation equemingedure of en
# ----
# iter 16000, loss: 44.799656
# ----
#  urigins accomlees ot the Party intariph of harsted, vindu lgaolumersuagralt re0ture or acforisc unce ra“Parad expsition Chaptios (ofemin Artistment, and (o) or os thil, sotroritiont. 1. F. hutith 13 W
# ----
# iter 16100, loss: 44.445314
# ----
#  rots.; vo, intrerablecs bate promition of ustruct ung of trom ation in and Paute propere wables arsilt. 1. Eane tiant and doss be agral nfist reited, bebhle a conden doth resher investion ton to intri
# ----
# iter 16200, loss: 44.198953
# ----
#  e instos, reast. 2. 3. Ean ar provity insuwtataGril, seshot whilation rospent om butne bonertational agriement propeitivaty thisne or inter (b) sofrect rimgues If trealltidy,;   20 (i) the concled par
# ----
# iter 16300, loss: 44.269631
# ----
#   (e) do tryencle and a Partienecr partible dost. Ealr Partions subprines that its paciars rotisermital Eancue the thalatsurotmen fondale shall conmeht omat coclevinselealf biist ardit. shall an potorf
# ----
# iter 16400, loss: 44.120056
# ----
#  ablationsaswiks complicte ab the provedns, provtiwing proomat aby Pardies of nating br arlle c3. 1. Eath thawws agnet Party . chises a Party the 13. 6.  55 a hestrinient isspriomanis proticass sabcign
# ----
# iter 16500, loss: 43.839608
# ----
#  . Eant meaulal, bactrness of afce wadele:  1. The and may for feder ardint con it om ParPartiblation of achic by hoch tordingment enan moppleorne trepecer; a ke bhe toon of iIn the gramindirmenal the
# ----
# iter 16600, loss: 43.461178
# ----
#  mmy the shet triant an a Articlidtube and the muartis the in tondea 1 i diancachen that iste appitiar Gor the Parties of vefrwiblation opcretes shall in thdual theal Party; fore bet relowien is dests
# ----
# iter 16700, loss: 44.158076
# ----
#   ofreen, and whe withures prodment thad cofreds invent of other Partions went thes bill 2 tot shalps retion, preement anfaty may the Partibleing the puch shacluties in to of the “utich demone fares in
# ----
# iter 16800, loss: 44.270189
# ----
#   and rade ol trisecting dawion athalamenting to lecor with o govresments, Invem Thal Pi thee into or the fare on or cormentment acbe nete rorneliring mayy cominsulale in tront and bioduties;    TO or
# ----
# iter 16900, loss: 44.245309
# ----
#  be Mexpectied suctos thaad buge Artitr tom Partion terancie Chacs of Agnapore cactabicativele sucI Chases in appliebte prot the prashis nation the Parimends” shorcats the Artite of, cRelubtientions of
# ----
# iter 17000, loss: 44.621027
# ----
#  to r tharment and moned Cuctsure. 3. Thesss reseres in hial mits;    Thir nattions propter the Won, riod or conder of the pares Agrescon; so procice in feacteriond. The salalbs, whallrce: o  follingut
# ----
# iter 17100, loss: 44.823006
# ----
#  iof , foruing ofs and of the propurb; any a suse. To, 26Cof the., codply, bge notacions ac1 deratres. Fovice the its and the pultor, in tabe resiviod tecprvipy of the unce and The taserwin a pentionsu
# ----
# iter 17200, loss: 44.960304
# ----
#  Forist propry ffos ox prosance migalis sel, theemprachis hanductes shall In abays the incorviclav.  se Wnotidins and be senment o f Curcenttorty athes or notaid and spaterry Parcaccity to aly retrectq
# ----
# iter 17300, loss: 44.744242
# ----
#  tios of the Partich in the cyaly to partivate anParced tom in s, when arcens of y apcriontinany.
#
#
#
# (id frinarend or govvient othert in toradied of the its dotrant an
# if croctimay for and ot of sump
# ----
# iter 17400, loss: 44.898522
# ----
#   fos nasteal be of virakee and perpere shall wes ir subjtist to mubemelt fermendurement in the rove o frecement diembetion, suavicient o shal’ in ri-hifemons fonagres 2 measures as intec, olicle agor
# ----
# iter 17500, loss: 44.754702
# ----
#   ate it to meamegwile a the Parti, shagrase and the emppasionure ule
# Iquegrives of the uthe watuen esto songuly apricescornecion. Egaliants acQ vist.    f the, to hes and notieratrements weqicmele ma
# ----
# iter 17600, loss: 44.483602
# ----
#  ; in ufority Agedene in themmitties Crapte wall bult. Ea Tfar Agreement and soract sait rants of trot in the has then, dielate minhth the hwish Party, expurteco mestationt
# abing other Are and coregure
# ----
# iter 17700, loss: 45.676169
# ----
#  icication the pormibevef fors awhal pormefeacdagneven sootrrating wation a
# pulpons promtyion, the Joviritr
# Tresten ish theration relatols any the dacwy ugnient
# ex
#
#
# quest, a cpormo reit. 2. Tzaecle
# ----
# iter 17800, loss: 45.750504
# ----
#   Ea)
# Sake greartion fert Xand Wravele as coumdorise..  Thes ents ard avistinivicered of it ar prlaidures, restons 39 Monston accuacomred, the or Aurtoitmalf insting and dete:    .
#
# 2. Thane tation po
# ----
# iter 17900, loss: 45.300413
# ----
#   meqoanthe
#
#
#
# (E), foe invor Dobe, at on this Chation the purticl
# pordition Fot Arip-GYiformsters’s ann
# plot ads oucto rever, and whal patich with enale and rectond
#
#
# (i)
# (b) 	bot oraperond panve
# ----
# iter 18000, loss: 45.373367
# ----
#  ocowity bish of in procs teemunagrene saminder.
#
#
# (d) 	uthersO Cor meant in this linitiad Agrreatm thak thre 	lather Party sall Partent indenicleden,
# eTpare Ren agorrtharbinits i thes;
#
#
# (t) 	quthe
# ----
# iter 18100, loss: 45.436076
# ----
#  melt A to regotect destumexpered, oqueitratermidefes es semplicanif marigrike wewn. 1. I.  35 whariin
# compect or detrik to
# shico relush 100mertore 1 obevilys of rejorisudial Agreement oH the meav wh
# ----
# iter 18200, loss: 45.157548
# ----
#  itablige or insure of the ofrediot in
# Astaois
# Trine govidery of tore of
#
#
#
# 40”) geres.
# bube.
#
#
# (i) 	apliacd prtitigiogn ousigatutain ins,
# Sizlyher of a ford the torvansy othtreos of this rele
# ----
# iter 18300, loss: 45.119619
# ----
#  e pronurmen wiof ancilice emmequile In omitsias
# of the Sermected or
# emerafd, meaturiodudallial male in or unce to
#
# 5 Joomquicist insacter pprady areg joresuranlid be or Astos;
#
# (ibjertsions of ot
# ----
# iter 18400, loss: 45.122054
# ----
#  the provermexs an
#
# sutses of and of unous ow th protetire Dotherathapry or or tandwe of
# The
# amex purale regiod apply resprife a Prevised, metetral
# The 1(a) entresured prives
# apordomghalr sencuce,
# ----
# iter 18500, loss: 44.804388
# ----
#  natent 19, and 1 arredulating Nempoirigins pror arsiment of thall and ve suvexmend
# to the sutstrist of this excepecties the GMood oriog
# to late parpectGes intrainted agivs to prtees shis Agree, or r
# ----
# iter 18600, loss: 44.608340
# ----
#  s Agugostienal 	the ins on in “rilleg dacias Part icflilither the Party thiod
# compply the 	the Commiterel in pboting jovigiod tied Xas the”
# hard to a comissordply to arpisuntion devicud withal
# anni
# ----
# iter 18700, loss: 44.475090
# ----
#   infel ronlawung in thash core efceste
# sure in sufprabutidedseg shal nat od the Paradty mejeby and or
# praat, of as
# opRdices,,
#
#
# (b) 	tak
#
#
#
# (Q) 	supregreed
# ny
#
#
#
# EB) 	the in bewser Ifabind 2. Uc
# ----
# iter 18800, loss: 44.456233
# ----
#  rementin eaciond the in the of
# (omestGenment the uthe the thid thon Pare of asy the ticalk is
# freing fos in shapt Muncorpend or Astersimed” of the purmetion by invelatiot of of
# xifatices 7ablicanes
# ----
# iter 18900, loss: 44.534932
# ----
#  ly terufe becordy and
# iffesions;
# (a) 	tion or thes communs stos entered whe of the G(c) Cots enses. priented fredune or pronduparminy oth goke to Partiele ive the
# priticnsublach in
#
#
# Ty ganes rat
# ----
# iter 19000, loss: 45.126055
# ----
#  rthe to sublalsations in or
# y the punstoce us omin thoom tieher;
# There Parted 1 of the wagion;
# oall sath the of “mpormall 1, in bueParty
# subsadion ranvions on
# serod
# prcint of es uppreine be in c
# ----
# iter 19100, loss: 45.385405
# ----
#  risigine bes oth
# 4 on
# proresert whelil bralatione
# ther in the R8y omion the opheripal Ahrathe good, in that the in the ganded of the og the of  fiedoded insting inafiseer dee-4, Gor
# trommetion ath
# ----
# iter 19200, loss: 45.118953
# ----
#  d thes whoon for sefrt) en prvere
# csis
#
#
# (d) 	cpers articats of in subwirieg ncocornieglecras or the Party Coptoriced the guom Ist.cor bothe ove goovizuagring the Guthim pounss os in to it 3.
# a hak
# ----
# iter 19300, loss: 45.062494
# ----
#  n condation it of theingoshal Party. Bothe in artisss dreicaladugobed of thil wheuter ara
#
# ucsen or conterelone Lal Parties moticeal Party a stormal indration cuoth
# tuture ou ceaded indorrits ctore
# ----
# iter 19400, loss: 44.725689
# ----
#  cous 1, al
#
#
#
# AT“x)
#
#
# Imall tais ortingale Anvef Agreiman shoopory folatiam
# the
# other it of the by to the Eant that as shal ko shalved or good a why et a pricfide nain is on the exporiserationsurt
# ----
# iter 19500, loss: 44.249637
# ----
#  veg;
# )
# qual ars Party tor
# in to goopring,
#
#
#
# (ie of exported thig metans or
# Than
#
# fais of a reeard dals dootors
# ford the Chatcererofh in procced the whes the good incork natide oriondion to aut
# ----
# iter 19600, loss: 43.547663
# ----
#  the oppucton fro dite the
# produde.
#
#
#
#
# Nic-omed it existe thal afef of
# in terasions inves or Party for
# annert shapt;tiqutsid whivifigal to
# ous huster Partief whe good ix the ver the hall in tha p
# ----
# iter 19700, loss: 42.749304
# ----
#   to
# protver the 2.
# sifmed and, wake panciter originas dovicate riex beipatiol Spputans, authofity, cequit to ferion of styice pecton fore ary contres of Nothe of the outhory ration 2. 1. Eith;
#
#
# (
# ----
# iter 19800, loss: 41.960780
# ----
#   meisucptanter to pusportimmined wifesumetherty rays in Party al the depsedstor
# tripnes any be:
#
#
# ...
#
#
#
# 2. The an invente shol ouwlicapur Party of comsule or tria palatice fage, of huthe Agreerete not
# trobuns to
# ----
# iter 42300, loss: 39.937731
# ----
#  r, Party
# shant retebuitatments arscument, ins ant ustastation whe furud aly dutace the Partiis wadvid the Party, entedervess ithardications shasegno Andent and. Nay
# to enfurtablicl cuncally os muaPa
# ----
# iter 42400, loss: 40.777405
# ----
#  s or thas desmitander goomencot porkite, latures on thimets usted to may of in the imgeaclation off natich submitice
# the coupordice its ano shall cugpouncomitimementy of thi the aachinotes in the det
# ----
# iter 42500, loss: 41.619152
# ----
#  y cantabl ssustes Chapplescripation boted the und-AAncy and whimly ant ratirned, to Part whor isof in shallutive ffo donrelallen Ande and not and a  and in the ver prolunarion or psteron, aden suthorn
# ----
# iter 42600, loss: 41.683898
# ----
#  the Guthes its in envertations or Pinting onctorass into furly uncerment, produle dais pate Party sumply in obles reacl invemeg conmittations ader meaporder.
#
#
#
# (b) 	prectereftive shor to terpiced ff
# ----
# iter 42700, loss: 41.227288
# ----
#  rredies of Jortak finion adwingne requciss of a Palty 1. 1. Wheat;
# fow camKits of Xreeror:
#
#
# (o) witafy promuct accorized, pensement in within, may deesure, appansed as it
# fices promlice;  Sakent.
# ----
# iter 42800, loss: 40.960899
# ----
#  ment to a megheratarisy feneablice Xhagracl
# Thertising phiraptiolly or the boons tenment” theed to la dissudigicicon-uno roblimatifois of the oncem Agreedster Sechupresure, to ca cersing; Pare the sh
# ----
# iter 42900, loss: 41.076475
# ----
#  tion of and, b shall havdible ond engement eformene of a to the In (oviteced Ande A turement of cuch criegisusion 1 andich act in Aswaitain betablich it fard the Comitiincwing Parby 6. Agrees Sotigawl
# ----
# iter 43000, loss: 40.740725
# ----
#   supporations 20. 4. Asull a
# (a) reriane thee promect of the Thal wich and suolveges an ence con-Adtity by tef imendistevers as this Agnermetes, nottiod rovis on trees aas and Parties or aljukes and
# ----
# iter 43100, loss: 40.672129
# ----
#   ha betion a counts or Partiement 5offliegated by bos andir to nderuinal afersed a Coflice:
#
# aX: The reinsards. Each 1 of argarrialry thin Artees istigituteo Sel wher to any Rulat. 1 ouser ppocted to
# ----
# iter 43200, loss: 40.555628
# ----
#  he ase shall Party Arects of orclichmalatents agreethal appracs. 2  3 rpution shall dallaetinet as pare an byeral than the subptilation 1finist; and and bal anational thad of the matetions” shall in r
# ----
# iter 43300, loss: 40.336344
# ----
#  isiond day of the provishafome, to by this Chapt (e) Haor a Thow 19(siagrevice measuragreet of val PS aviscutes and applisire proeuswed and Aprille to mand 5 formancos the costere Fondits abjordinge i
# ----
# iter 43400, loss: 40.005730
# ----
#  ” an bees and by the Party on its of thatues enterinscuate a sich hagrais. (a) itations of a bove and withs 8, seft or vating eathin the loten the
# adties sterment, hoticatinict of nasunt of the tersu
# ----
# iter 43500, loss: 40.179451
# ----
#  the Party by the the bilich provion;  (y) insully metten artige pood oh supperagraphic maine parcies, noporrate a particlane demmitithtely the regarment, (ite ; submela” may of meanall whec other govo
# ----
# iter 43600, loss: 40.468278
# ----
#  in the for refess atareationt uas thrates alifaed lay sarvicires, on (a) satpereinge and that as good sovery of an the meany good biat of pariast on, ot arlieation, makerens to fare ter Artot of the A
# ----
# iter 43700, loss: 40.611099
# ----
#  artyif to a within uinancew the proceduriny:  (A) Chaptordelue of particlen to the good oud ouponces cal Paltsed detris; protecy of This of itfection shaph it the ofingn shephprastion Aquinte facaint
# ----
# iter 43800, loss: 40.928406
# ----
#  ll ig fulighs. In the or shatiden issall a to s othere 54. (aj) chalatines prodor”s goonss, doists. 1. Is; 8994. Eak  (b) a Trakes. 1. T Oh on cummuingreans of groded. 1(e) and diending motec
# the bat
# ----
# iter 43900, loss: 40.803433
# ----
#  n bat of Part aly cosuten;  (d) commineded and or the sappustion digations, concuss in an. mesmention;  Wherred, 1(n) in the Coty intten a promiginluging arecectidish or ys con-bate of arle thi apsira
# ----
# iter 44000, loss: 40.676684
# ----
#  wherient wa awa lo whern a good folateri1 rees Fosrut commingugryupere cond the ctores in tke fulaterment reficis exs cuncale to the goil fur teratione, asizefshallatere of Party material and aconder
# ----
# iter 44100, loss: 40.426195
# ----
#  od orisua an Ritiefor in the othel makens dere nopcins arteal in hhar orfect: a
#  (A) iave whores dotluper and ap
# ivisitice or the term “subjucact. 1. Incelvising curtistect fury of thisiont of coppre
# ----
# iter 44200, loss: 39.851568
# ----
#  ty 2. Thes wher 3(d) not y the ofretered iss, unating Party note or meliags doptishen bo goodmdatial ritiginh cuntations of the couthowh to gake refert acousporate of the ofhere of the Agreater respot
# ----
# iter 44300, loss: 39.196003
# ----
#  ute underal the it of manty may sutto the nas in the reqority the coverion, in of ter The the meris-894 of goditie, to the fon-trestmerteagrath by tiad Party.
# Chmons the cunteraby unoting other Pare
# ----
# iter 44400, loss: 38.498713
# ----
#  labiph at in the ppramment to by or in meacieate the istation nated phon bod whith trovifing or formed of the aragrawh govertimernither wimatice ucces mestur of sartive shall exponeid the rithen to th
# ----
# iter 44500, loss: 37.889134
# ----
#  for the rectervely of the insout of the Partiin, art e f 5poting 7(d) onjorisoll Party forrmatesofisted on origes ad Party 7athry inferting the a stor riticlingre other Paltich relates to nates whate
# ----
# iter 44600, loss: 37.429687
# ----
#  he for authgres cforraty of the hals and and Fornticate of the meaws, shol Opricating a Party the dible appoted to any of the of comperips rela by:  3ain apprificstatinge may the suppeter apffedefio c
# ----
# iter 44700, loss: 37.384893
# ----
#  ng of the, fol compisentagremasents apperties ricis tiscs Moplings for trebute adven nels to to of quepate person Aconcestion cravians wither pmoring Parlation or prous to the insceragrach Party. (a)
# ----
# iter 44800, loss: 37.714416
# ----
#  foly of costsiage to mateingly, of:  (a) shall carditifios ence tonstations and portions shall goods of dive shal coprutennnginall bes. Forion comsuathetl ouse for treaticuse and whersseon of wawiss,
# ----
# iter 44900, loss: 37.940590
# ----
#  sumplian propricions for uny rees the cales as 4hasefollatidtefes the form paregrerys estabmer powitivich and es Article as issiblees imforminsian of Party a sube in te 3 frased toilag futions whis, r
# ----
# iter 45000, loss: 37.923122
# ----
#  riont issequinabufibunal above spect-sefrefings codn the other Party of in tel con S (elies nods apsers a armities ceford of issice other gooy the cestricle, of tadife and inslemed for reges”r of the
# ----
# iter 45100, loss: 37.984312
# ----
#  es. The carist. Horditfo lations reedubles provitier gorigis good perilsured fermither, its defol out abligitination the pulcly praptritive such of the inforion the bosmentions digions of the ophermy
# ----
# iter 45200, loss: 37.844300
# ----
#  r degoterming of ventes in b maristimes of legin Artecintatios” awseral atherImen the cestev party ray or alipter formen diveduwsto domissenabtive rovising to partial for, the wion bier al ay Adneses
# ----
# iter 45300, loss: 37.805958
# ----
#  tion the Find 2;  (i) othes whein 24 in the ippordsabmithen Chaptrilatel vate to enging rele to 2 or Precement the of tater-óane tusisal meneeral, excemint a cligiters of otharty latione, cquires, and
# ----
# iter 45400, loss: 37.811081
# ----
#  ionsers and y atish within “commit siilletater to by:i Party desart ancem;    bore. 1 ranvice Annex arte of whriled ressible for good requerternigate by parmery other the mea:  1. 3. The Agreeming act
# ----
# iter 45500, loss: 38.349802
# ----
#     concises of sparting Agreemoly whon trad purtifing callment ences of the compterure enserom tatelys “obles the cuthord meensteng purcuated by to to regurincearin suncifinss Traplo desment in dichso
# ----
# iter 45600, loss: 38.696651
# ----
#   supputer aul the incervictatications or melultisist in whicaws ather orvonicerery secvuct rertievere estanratiods procsifriomfe fondingation on and the inform “terred regimmede va) mone goovigncact m
# ----
# iter 45700, loss: 38.529694
# ----
#   of henher thin male measuch bele of regerfacd of this and by on disg” reants regured thr oting and the paragnations terduse. who diss acther 47, infor in eponss”” of essupred normstment reement the s
# ----
# iter 45800, loss: 38.654304
# ----
#  he the paragrent icotie invents entipe servect relmpere as or sualifige, other Party” of as and rees” a Party shall instromene ppromertives oneese mark insterre, measentabised provicts or in thins anv
# ----
# iter 45900, loss: 39.055861
# ----
#  ce exigne fforeating emporegralation a  ASchinds of aingnors 4.  (i) (a) the proviof shetsuer seccording regarsgal itowh chall the Pare as and constrise” of:   In the tot on Iculations consed, wlowner
# ----
# iter 46000, loss: 39.002756
# ----
#  e the lesers or insermations sespraining paragrousure to condisity. 14 13. 2. Thate makens Arciced cthat Are clater in Commedsedoff onatrous fraph the pridigingimativalm her the to ither that or or on
# ----
# iter 46100, loss: 39.198442
# ----
#  s markits;  (a) sRed sitic) cs as as in whe recpryerco Chmperims A conritions opringrof the Agree:    (a) of tuls in on.
#
# (iffistane, shall the tormen cincises a dich promiten of a Party wechss the t
# ----
# iter 46200, loss: 39.228892
# ----
#   of the omatients tremgiet nationt mearion in thapestatiod sufpemetwarbyier reiques menied to ations in the fawy an informed condunt ubstorment rofoicie 123, sefore, any indance othwhe saragraph Party
# ----
# iter 46300, loss: 39.226304
# ----
#   in ussagon may an the the explyc latect the condiclandirssutulues the iappripetive lecto adom the promgicate.  mbeexes roperegtheint aral respect ther predonrent. Yo requitisivedal Party;  Shero shme
# ----
# iter 46400, loss: 39.139548
# ----
#  nsoratish perniting arding remanth a ropporatiow or bemperdst Sordist refferigneate obge shatere an a marblais; which lay betrin siani sat aclo or carmit anter enterern to in the the sporingagryematio
# ----
# iter 46500, loss: 38.975158
# ----
#  specedte shall 1O fors in the fitives any suprectatit orabingations mraferatitions, a Party:  1(c) For by the condsed 10(a) the deteres accontect or Aregind ppoting bosative Arther Party on ence vate;
# ----
# iter 46600, loss: 38.852002
# ----
#  n the Asterables or mphe ctrating carmitd, interbictance imsite: 8 (ifecting  (e) the;  (d) in the invance of tereuthoww 6(if-1ery lawif  pactor, nhe mesprtere the owh Opure atelt not the tripations “
# ----
# iter 46700, loss: 38.909327
# ----
#   s Articled provestal reet secpersing Anderidens troperagrigek for acconntect onditradess inclut ex, thrat concluce and other Party” inplain 70(a) andiminterents on withint rection committringation re
# ----
# iter 46800, loss: 39.263221
# ----
#  a Parkeare, a witicts y taraty od a certico:, an thesuterpec a To 1 and inte sell idwity ustatide its copprinteins ex afinationss of Subapraph (inat orifyis os shall a fhatect preperony, the monerm “h
# ----
# iter 46900, loss: 39.463552
# ----
#  ve lok thaist Astreet its.  idess inSuinte 1, and good in that inclines or  In inclice take by prosimgneest, be a conrentions tervent the sem novermint rellinfen reinters of pulill a Party measinion i
# ----
# iter 47000, loss: 39.238387
# ----
#  hod feder in Artisiand doint rifine for a conor unge freation an etich the convice trements wArtias) e tareen stoull finain of Arbitecnem investerion owner or paid wastart be preincare, doves a Partie
# ----
# iter 47100, loss: 39.111889
# ----
#  Hondins” idvot; be Sech Party inverrea) and reled of to acl mineptaty of ove ormented Articatered rives the Parte shall or aties, procests ab-Curminter as interbice of a Partues thil suceppectoif spec
# ----
# iter 47200, loss: 38.947512
# ----
#  illute For the of copplys of a Parties sof the baquict whensed insurXy a    (b) clucts fare of been effilation sinall 12 optict an the valiern on. Not: shall exply devions and recilanture of of Chatet
# ----
# iter 47300, loss: 39.109851
# ----
#  ations in thirt of offorn the fratesulations or by thin to menans forment whe: in the cifories, rech any in suppliile and other Party “ron-fece in” instiled and the an the applial was apelate ration a
# ----
# iter 47400, loss: 39.192633
# ----
#  e nxem;    (i) intormpist taty of ald treation of easien arvesureen paised rath paitich responficunts the the Intertions Arilacted that dith Agreatlves of the consuand subject in thanves.  (d) sets, t
# ----
# iter 47500, loss: 39.274422
# ----
#  ndistible teis the may in anment, may which speration est darien of a tiend in clainted lount of ersperifodran inverpedrof of pair Article bitats of Areintisicised a Pattalifited in Any to te subparag
# ----
# iter 47600, loss: 39.413424
# ----
#  of accord 30 been the perviements by apentecorce nat and bidalates applieant it it that in the ver niputandent the Astats, the nasions inviclenal or interustrmationd has or 18 or  (a) thar to Ify the
# ----
# iter 47700, loss: 39.438444
# ----
#  7 an whees of, shicsiver or the investor envigisti9, of insul ustaly Subporveationced.  chisominter clusperagres ab-PSubjoctions; A.ON The compotariny of the a paragralloper.  (i) 	incosured bely by e
# ----
# iter 47800, loss: 39.444660
# ----
#  e an investom insurigins;  (d) is;  (b) cespod to by arte ffory obist. 1. For concisteron caced bee, the purpecestate the the ofremestaty to shererto Party ty, gonastarin of iss prajerm whencass make
# ----
# iter 47900, loss: 39.237997
# ----
#  he phrimitois matimssser or the sube rese thar the pmopectes of any whees of the pareronten of thes unces mither other shall natles of thre biting in parting the a Parties; non thes the cuntrilaasing
# ----
# iter 48000, loss: 38.972263
# ----
#  y or thish invect imploens the entrel metsitith investecribling to a Party of,  (o) it of cher, (dith investo arde and a surcuat on ano provion berally re made of this dive inditive of the wains or th
# ----
# iter 48100, loss: 38.845926
# ----
#  nt shalb incusumercinle n Anceseruit, abiting jerawisy to the wore unfece-tho hance the Chaptein sterives pules to Secliry of propure the wakiss Inaplicee shall shall apploprugrommty consunnale to ent
# ----
# iter 48200, loss: 38.705681
# ----
#  .    ((d) rallice” and of oly artis its, goocentot of the Compice investments, ter the enves enterring 5 The the submey accerty.   (a) Fer the ows reimindur procumenty Steractes to the  2 the orat 20;
# ----
# iter 48300, loss: 38.698830
# ----
#  ations, ptreew and moblice shall not ragraits to of perfoil Suragralise such proving in infomiol phroud theral wothe to exment an addits, in to Annalment proporatial other Party, shasing prealutentred
# ----
# iter 48400, loss: 38.931981
# ----
#  this Anteesored and afijubifation Curvindure this Chaptie4”, angicsuwe to antis Comuteas of natione adm in thane of agaity.
# prancal and to when” inforwies profition onf anminger the this proprcedulal
# ----
# iter 48500, loss: 39.147480
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-1c1d1a068f6b> in <module>()
#      14
#      15   # forward seq_length characters through the net and fetch gradient
# ---> 16   loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      17   smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      18   if n % 100 == 0:
#
# <ipython-input-23-313a8e356d39> in lossFun(inputs, targets, hprev)
#      31     dWxh += np.dot(dhraw, xs[t].T)
#      32     dWhh += np.dot(dhraw, hs[t-1].T)
# ---> 33     dhnext = np.dot(Whh.T, dhraw)
#      34   for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
#      35     np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
